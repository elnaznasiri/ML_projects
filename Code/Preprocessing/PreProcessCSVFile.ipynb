# %%
import hazm as hz
import pandas as pd

# %%
baseFile = 'D:\DataEngineeringProject\persiandic.xlsx'

df = pd.read_excel(baseFile)
norm = hz.Normalizer()


for word in df['mean']:
    print(word)
# Out:
#  اجداد، اسلاف، پدران، پیشینیان، نیاکان & اخلاف
#  آبجی، اخت، باجی، خواهر، دده، شاباجی، همشیره & داداش
#  1 برپا، دایر، معمور 2 پررونق 3 پیشرفته، توسعه‌یافته، مترقی 4 تندرست، سالم 5 بسامان، منظم 6 غنی، مرفه & 1 خراب، متروک، ویران 2 بی‌رونق 4 عقب‌مانده
#  1 آباد، برپا، پررونق، دایر، معمور & خراب
#  1 آبادی، عمارت، عمران 2 ترقی، توسعه، رونق 3 آسایش، ترفیه، رفاه & خرابی
#  1 آبادانی، عمارت، عمران 2 ده، دهات، دهکده، روستا، شهر، واحه، ولایت
#  1 آبان‌ماه، عقرب 2 آب‌بان
#  1 برکه 2 آبدان، آبگیر، برم، تالاب
#  1 آب‌ورز، سباح، شناگر، شناور 2 غواص
#  1 غوص 2 آب‌ورزی، سباحت، شناگری
#  بند، سد، ورغ
#  فقاع، فوگان، ماء‌الشعیر
#  آباجی، اخت، باجی، خواهر، دده، شاباجی، همشیره & داداش، برادر
#  1 تقدیر، سرنوشت، قسمت 2 بهره، روزی، نصیب 3 آبشخور، مشرب، منهل
#  1 تنگ، سبو، کوزه، مشربه 2 آبخور، آبشخور
#  آب‌دار، آبزا، کوهه، موج، موج‌کوهه
# ...

# %%
for word in df['mean']:
    #print(word)
    print(norm.normalize(word))
# Out:
#  اجداد، اسلاف، پدران، پیشینیان، نیاکان & اخلاف
#  آبجی، اخت، باجی، خواهر، دده، شاباجی، همشیره & داداش
#  ۱ برپا، دایر، معمور ۲ پررونق ۳ پیشرفته، توسعه‌یافته، مترقی ۴ تندرست، سالم ۵ بسامان، منظم ۶ غنی، مرفه & ۱ خراب، متروک، ویران ۲ بی‌رونق ۴ عقب‌مانده
#  ۱ آباد، برپا، پررونق، دایر، معمور & خراب
#  ۱ آبادی، عمارت، عمران ۲ ترقی، توسعه، رونق ۳ آسایش، ترفیه، رفاه & خرابی
#  ۱ آبادانی، عمارت، عمران ۲ ده، دهات، دهکده، روستا، شهر، واحه، ولایت
#  ۱ آبان‌ماه، عقرب ۲ آب‌بان
#  ۱ برکه ۲ آبدان، آبگیر، برم، تالاب
#  ۱ آب‌ورز، سباح، شناگر، شناور ۲ غواص
#  ۱ غوص ۲ آب‌ورزی، سباحت، شناگری
#  بند، سد، ورغ
#  فقاع، فوگان، ماء‌الشعیر
#  آباجی، اخت، باجی، خواهر، دده، شاباجی، همشیره & داداش، برادر
#  ۱ تقدیر، سرنوشت، قسمت ۲ بهره، روزی، نصیب ۳ آبشخور، مشرب، منهل
#  ۱ تنگ، سبو، کوزه، مشربه ۲ آبخور، آبشخور
#  آب‌دار، آبزا، کوهه، موج، موج‌کوهه
# ...
